# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\hsoon\anaconda3\lib\site-packages (0.9.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hsoon\anaconda3\lib\site-packages (from librosa) (21.0)
# Requirement already satisfied: numba>=0.45.1 in c:\users\hsoon\anaconda3\lib\site-packages (from librosa) (0.54.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\hsoon\anaconda3\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\hsoon\anaconda3\lib\site-packages (from librosa) (0.24.2)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\hsoon\anaconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\hsoon\anaconda3\lib\site-packages (from librosa) (5.1.0)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\hsoon\anaconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\hsoon\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\hsoon\anaconda3\lib\site-packages (from librosa) (1.20.3)
# Requirement already satisfied: audioread>=2.1.5 in c:\users\hsoon\anaconda3\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\hsoon\anaconda3\lib\site-packages (from librosa) (1.7.1)
# Requirement already satisfied: setuptools in c:\users\hsoon\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (58.0.4)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\hsoon\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (0.37.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\hsoon\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (3.0.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\hsoon\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.26.0)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\hsoon\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hsoon\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hsoon\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hsoon\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hsoon\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.2)
# Requirement already satisfied: six>=1.3 in c:\users\hsoon\anaconda3\lib\site-packages (from resampy>=0.2.2->librosa) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hsoon\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\hsoon\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\hsoon\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = 'datasets/flaps.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate) # Need to use waveshow instead of waveplot 
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename)

# %%
wave_sample_rate
wave_audio
data
# Out:
# array([0.        , 0.        , 0.        , ..., 0.00307533, 0.00142199,
#        0.        ], dtype=float32)

# %%
import pandas as pd
metadata=pd.read
